# %% [markdown]
# # Creating basic grafics using Seaborn and Matplotlib

# %% [markdown]
# ### Data from: https://www.kaggle.com/abcsds/pokemon

# %% [markdown]
# ##### Everything I create, in my profile, in Python I'll try to create as equal as possible in R.

# %%
# Importing the packages we will use

import matplotlib.pyplot as plt  
import seaborn as sns 
import pandas as pd

# %%
# Pre-processing

df = pd.read_csv('Pokemon.csv')

# df['Legendary'] is, originaly, a boolean which True means de pokemon is legendary and False the opposity.

df['Legendary'] = df['Legendary'].apply(lambda x: 'Not Legendary' if x == False else 'Legendary')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation      Legendary
# 0       65       65     45           1  Not Legendary
# 1       80       80     60           1  Not Legendary
# 2      100      100     80           1  Not Legendary
# 3      122      120     80           1  Not Legendary
# 4       60       50     65           1  Not Legendary

# %%
# One Scatterplot Chart

sns.scatterplot(x = 'HP', y = 'Attack', hue = 'Legendary', 
            data = df, style = 'Legendary')
sns.despine(offset = 2, trim = False)
plt.title('Scatterplot Chart Example')
plt.xlabel('HP')
plt.xlim([0, 300])
plt.ylabel('Attack')
plt.ylim([0, 200])
# Out:
# (0, 200)

# %%
# Several Scatterplot Charts

sns.relplot(x = 'HP', y = 'Attack', hue = 'Legendary', 
            data = df, style = 'Legendary', col = 'Generation',
            col_wrap = 3)
plt.xlabel('HP')
plt.xlim([0, 300])
plt.ylabel('Attack')
plt.ylim([0, 200])
# Out:
# (0, 200)

# %%
# Bar Chart

sns.countplot(x = 'Generation', data = df, color = 'blue')
plt.title('Bar Chart Example')
plt.xlabel('Generation')
plt.ylabel('Count')
plt.ylim([0, 170])
# Out:
# (0, 170)

# %%
# BoxPlot chart

sns.boxplot(x = 'Legendary', y = 'HP', data = df, hue = 'Legendary', dodge=False)
plt.title('BoxPlot Chart Example')
plt.xlabel('Legendary')
plt.ylabel('HP')
# Out:
# Text(0, 0.5, 'HP')

# %%
# Density chart

leg = df.HP[(df.HP) & (df.Legendary == 'Legendary')]
notleg = df.HP[(df.HP) & (df.Legendary == 'Not Legendary')]
sns.kdeplot(data = notleg, shade = True)
sns.kdeplot(data = leg, shade = True)
sns.despine(trim = False)
plt.title('Density Chard Example')
plt.xlabel('HP')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
# Histogram Chart

sns.distplot(df['HP'], kde = False, bins = 15, color = 'blue')
sns.despine(trim = False)
plt.title('Histogram Chart Example')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
